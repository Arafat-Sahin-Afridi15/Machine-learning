# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/smoking_driking_dataset_Ver01.csv')
df.head(3)
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
#
#    serum_creatinine  SGOT_AST  SGOT_ALT  gamma_GTP  SMK_stat_type_cd  DRK_YN
# 0               1.0      21.0      35.0       40.0               1.0       Y
# 1               0.9      20.0      36.0       27.0               3.0       N
# 2               0.9      47.0      32.0       68.0               1.0       N
#
# [3 rows x 24 columns]

# %%
#check null value
df.isna().sum()
# Out:
# sex                 0
# age                 0
# height              0
# weight              0
# waistline           0
# sight_left          1
# sight_right         1
# hear_left           1
# hear_right          1
# SBP                 1
# DBP                 1
# BLDS                1
# tot_chole           1
# HDL_chole           1
# LDL_chole           1
# triglyceride        1
# hemoglobin          1
# urine_protein       1
# serum_creatinine    1
# SGOT_AST            1
# SGOT_ALT            1
# gamma_GTP           1
# SMK_stat_type_cd    1
# DRK_YN              1
# dtype: int64

# %%
x = df.iloc[:,0:3]
x
# Out:
#           sex  age  height
# 0        Male   35     170
# 1        Male   30     180
# 2        Male   40     165
# 3        Male   50     175
# 4        Male   50     165
# ...       ...  ...     ...
# 18969    Male   55     170
# 18970    Male   70     165
# 18971  Female   45     150
# 18972    Male   25     165
# 18973    Male   60     165
#
# [18974 rows x 3 columns]

# %%
y = df.iloc[:,3:5]
y
# Out:
#        weight  waistline
# 0          75       90.0
# 1          80       89.0
# 2          75       91.0
# 3          80       91.0
# 4          60       80.0
# ...       ...        ...
# 18969      70       80.0
# 18970      65       75.0
# 18971      50       70.0
# 18972      60       71.0
# 18973      65       87.0
#
# [18974 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
x.sex = LabelEncoder().fit_transform(x.sex)
x.head()
# Out:
#    sex  age  height
# 0    1   35     170
# 1    1   30     180
# 2    1   40     165
# 3    1   50     175
# 4    1   50     165

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg = reg.fit(x_train,y_train)

# %%
reg.score(x_test, y_test)
# Out:
# 0.37320479625632724

# %%
from sklearn.preprocessing import LabelEncoder
lb =  LabelEncoder()
lb.fit(df['sex'])
df['sex_transformed'] = lb.transform(df['sex'])

# %%
df
# Out:
#           sex  age  height  weight  waistline  sight_left  sight_right  \
# 0        Male   35     170      75       90.0         1.0          1.0
# 1        Male   30     180      80       89.0         0.9          1.2
# 2        Male   40     165      75       91.0         1.2          1.5
# 3        Male   50     175      80       91.0         1.5          1.2
# 4        Male   50     165      60       80.0         1.0          1.2
# ...       ...  ...     ...     ...        ...         ...          ...
# 18969    Male   55     170      70       80.0         0.9          0.9
# 18970    Male   70     165      65       75.0         0.5          0.1
# 18971  Female   45     150      50       70.0         1.2          1.0
# 18972    Male   25     165      60       71.0         1.2          1.5
# 18973    Male   60     165      65       87.0         NaN          NaN
#
#        hear_left  hear_right    SBP  ...  triglyceride  hemoglobin  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18974 entries, 0 to 18973
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sex               18974 non-null  object
#  1   age               18974 non-null  int64
#  2   height            18974 non-null  int64
#  3   weight            18974 non-null  int64
#  4   waistline         18974 non-null  float64
#  5   sight_left        18973 non-null  float64
#  6   sight_right       18973 non-null  float64
#  7   hear_left         18973 non-null  float64
#  8   hear_right        18973 non-null  float64
#  9   SBP               18973 non-null  float64
#  10  DBP               18973 non-null  float64
#  11  BLDS              18973 non-null  float64
#  12  tot_chole         18973 non-null  float64
#  13  HDL_chole         18973 non-null  float64
#  14  LDL_chole         18973 non-null  float64
#  15  triglyceride      18973 non-null  float64
# ...

# %%
import seaborn as sn
sns.heatmap(df.corr())
# Out:
# <ipython-input-444-ba44739d8a71>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
x = df[['age','height','weight','waistline']]

# %%
x.head()
# Out:
#    age  height  weight  waistline
# 0   35     170      75       90.0
# 1   30     180      80       89.0
# 2   40     165      75       91.0
# 3   50     175      80       91.0
# 4   50     165      60       80.0

# %%
y = df[['sex_transformed']]
y.head()
# Out:
#    sex_transformed
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
from sklearn.model_selection import  train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.1)

# %%
from sklearn.tree import  DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.839831401475237

# %%
x = model.predict([[300,30,45.5,5.3]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
lb.inverse_transform(x)
# Out:
# array(['Female'], dtype=object)

# %%
lb.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(xtrain,ytrain.values)
# Out:
# <ipython-input-455-f911b6de06f7>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(xtrain,ytrain.values)
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.8551106427818757
